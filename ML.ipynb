# %%
import os
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
directory = 'MlDump'
pd.options.mode.chained_assignment = None   # !!!!!!!!!!!!! отключает вывод предупреждений pandas

# %%
DS = pd.DataFrame()

# %%
# Конкатенация всех дампов в один датафрейм
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        ds = pd.read_csv(f)
        DS = pd.concat([DS, ds])

# %%
# Сброс индекса
DS.reset_index(drop= True , inplace= True )

# %%
# Очистка датасета от лишних данных (убираем столбец со всеми значениями NaN и столбец с нумерацией строк)
del DS["bInterfaceClass"]
del ds["No."]

# %%
# Кодирование столбцов с текстовыми значениями
le_Source = LabelEncoder()
DS['Source_new'] = le_Source.fit_transform(DS.Source.values)
le_Destination = LabelEncoder()
DS['Destination_new'] = le_Destination.fit_transform(DS.Destination.values)
le_Protocol = LabelEncoder()
DS['Protocol_new'] = le_Protocol.fit_transform(DS.Protocol.values)
le_Info = LabelEncoder()
DS['Info_new'] = le_Info.fit_transform(DS.Info.values)

del DS["Source"]
del DS["Destination"]
del DS["Protocol"]
del DS["Info"]
DS['Flag'] = DS['ML']
del DS["ML"]

# %%
# Разбиваем датасет на обучающий набор данных и выборку валидации
DS_main = DS.loc[:int(len(DS)/2),:]
DS_valid = DS.loc[int(len(DS)/2):,:]
DS_valid.reset_index(drop= True , inplace= True )

# %%
# Выделение целевых переменных из массивов данных
main_X = DS_main.iloc[:,:-1]
main_Y = DS_main.iloc[:,-1]
valid_X = DS_valid.iloc[:,:-1]
valid_Y = DS_valid.iloc[:,-1]

# %%
# Разбиваем обучающий набор данных на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(main_X, main_Y, test_size=0.3, random_state=42)

# %%
clf = DecisionTreeClassifier(random_state=0)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
print(f"Точность ML-модели при обучении: {clf.score(X_test, y_test)}")
print(f"Точность ML-модели на тестовой выборке: {clf.score(valid_X, valid_Y)}")
# Out:
# Точность ML-модели при обучении: 0.9999541515748934
# Точность ML-модели на тестовой выборке: 0.9013144924280284

# %%
# Конвертируем прогноз модели в Pandas Series
attack_predict = pd.Series(clf.predict(valid_X))

# %%
# Обратное кодирование столбцов в текстовые значения
DS_valid['Source'] = le_Source.inverse_transform(DS_valid.Source_new.values)
DS_valid['Destination'] = le_Destination.inverse_transform(DS_valid.Destination_new.values)
DS_valid['Protocol'] = le_Protocol.inverse_transform(DS_valid.Protocol_new.values)
DS_valid['Info'] = le_Info.inverse_transform(DS_valid.Info_new.values)

del DS_valid["Source_new"]
del DS_valid["Destination_new"]
del DS_valid["Protocol_new"]
del DS_valid["Info_new"]

DS_valid['Class'] = DS_valid['Flag']
del DS_valid["Flag"]

# %%
# Добавляем столбец с результатаими работы ML-модели
DS_valid["Predict"] = attack_predict

# %%
print(f"Всего наблюдений в валидационном датасете: {len(DS_valid)}")
print(f"Всего размеченных атак: {DS_valid.Class.value_counts()[1]}")
print(f"Всего атак по версии ML-модели: {DS_valid.Predict.value_counts()[1]}")
# Out:
# Всего наблюдений в валидационном датасете: 218107
# Всего размеченных атак: 149553
# Всего атак по версии ML-модели: 145865

# %%
# Сравнение результатов работы модели с изначальной разметкой. Данная часть датасета визуализирует ddos-атаку
# Колонка Class - изначальная разметка (1 - атака, 0 - нормальный трафик), колонка Predict - результат работы ML-модели.
filt = DS_valid["Predict"] == 1
DS_valid[filt].head(30)
# Out:
#       No.        Time  Length           Source    Destination Protocol
# 0   97604  287.320751      54   213.119.82.215  192.168.10.10      TCP  \
# 1   97605  287.321648      54    228.34.114.48  192.168.10.10      TCP
# 2   97606  287.322597      54  134.247.197.118  192.168.10.10      TCP
# 3   97607  287.323768      54      9.12.158.91  192.168.10.10      TCP
# 4   97608  287.324673      54    104.199.10.36  192.168.10.10      TCP
# 5   97609  287.325674      54   114.182.15.192  192.168.10.10      TCP
# 6   97610  287.326847      54   172.147.71.250  192.168.10.10      TCP
# 7   97611  287.327977      54    220.232.240.4  192.168.10.10      TCP
# 8   97612  287.328872      54     135.64.61.66  192.168.10.10      TCP
# 9   97613  287.330358      54     52.12.216.22  192.168.10.10      TCP
# 10  97614  287.331560      54   149.30.157.131  192.168.10.10      TCP
# 11  97615  287.332556      54  129.167.125.117  192.168.10.10      TCP
# 12  97616  287.333493      54   161.237.192.60  192.168.10.10      TCP
# 13  97617  287.334466      54  164.228.232.132  192.168.10.10      TCP
# 14  97618  287.335601      54    175.171.57.13  192.168.10.10      TCP
# 15  97619  287.336632      54     61.53.30.171  192.168.10.10      TCP
# 16  97620  287.337632      54   188.66.206.171  192.168.10.10      TCP
# 17  97621  287.338619      54    68.225.105.35  192.168.10.10      TCP
# 18  97622  287.339875      54   139.140.140.82  192.168.10.10      TCP
# 19  97623  287.340898      54    129.194.26.43  192.168.10.10      TCP
# 20  97624  287.341914      54       2.197.6.12  192.168.10.10      TCP
# 21  97625  287.343259      54   189.223.222.90  192.168.10.10      TCP
# 22  97626  287.344349      54  246.199.184.156  192.168.10.10      TCP
# 23  97627  287.345474      54   157.76.170.159  192.168.10.10      TCP
# 24  97628  287.346569      54      3.187.44.31  192.168.10.10      TCP
# 25  97629  287.347808      54   19.181.209.142  192.168.10.10      TCP
# 26  97630  287.348886      54   164.209.70.142  192.168.10.10      TCP
# 27  97631  287.349907      54     78.13.96.217  192.168.10.10      TCP
# 28  97632  287.351385      54  114.152.243.158  192.168.10.10      TCP
# 29  97633  287.352396      54     25.203.29.32  192.168.10.10      TCP
#
#                                        Info  Class  Predict
# 0   37460  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 1   52200  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 2   23618  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 3   28621  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 4   21553  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 5    5957  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 6   50570  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 7    7948  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 8   48955  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 9   48911  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 10  54488  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 11   6329  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 12  13449  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 13  23205  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 14  23072  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 15  65222  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 16   6545  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 17   7549  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 18  56169  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 19  49261  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 20  53220  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 21  27252  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 22  59078  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 23  65513  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 24   9544  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 25  25084  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 26   9925  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 27  57025  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 28   4407  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1
# 29  40748  >  80 [SYN] Seq=0 Win=8192 Len=0      1        1

# %%
# Сравнение результатов работы модели по отлову ICMP пакетов с изначальной разметкой
# Колонка Class - изначальная разметка (1 - атака, 0 - нормальный трафик), колонка Predict - результат работы ML-модели.
filt = DS_valid["Protocol"] == "ICMP"
DS_valid[filt].head(50)
# Out:
#           No.        Time  Length        Source   Destination Protocol
# 10715  108319  310.187994      42  192.168.10.5  192.168.10.2     ICMP  \
# 10716  108320  320.190169      42  192.168.10.5  192.168.10.2     ICMP
# 10717  108321  330.192863      42  192.168.10.5  192.168.10.2     ICMP
# 10718  108322  340.195160      42  192.168.10.5  192.168.10.2     ICMP
# 10719  108323  350.198606      42  192.168.10.5  192.168.10.2     ICMP
# 10720  108324  360.201016      42  192.168.10.5  192.168.10.2     ICMP
Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10721  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10722  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10723  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10724  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10725  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10726  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10727  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10728  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10729  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10730  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10731  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10732  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10733  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10734  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10735  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10736  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10737  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10738  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10739  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10740  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10741  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10742  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10743  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10744  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10745  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10746  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10747  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10748  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10749  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 10750  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79326  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79327  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79328  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79329  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79330  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79331  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79332  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79333  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79334  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79335  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79336  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79337  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79338  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1
# 79339  Echo (ping) request  id=0x0000, seq=0/0, ttl=6...      1        1

# %%
# Сравнение результатов работы модели по отлову HTTP протокола с изначальной разметкой
# Колонка Class - изначальная разметка (1 - атака, 0 - нормальный трафик), колонка Predict - результат работы ML-модели.
filt = DS_valid["Protocol"] == "HTTP"
DS_valid[filt].head(50)
# Out:
#          No.       Time  Length        Source     Destination Protocol
# 18300   2401   5.686226     242  192.168.10.5  216.58.209.238     HTTP  \
# 18301   2402   5.686226     242  192.168.10.5  216.58.209.238     HTTP
# 21110   5211  51.359821     242  192.168.10.5  216.58.209.238     HTTP
# 21111   5212  51.359821     242  192.168.10.5  216.58.209.238     HTTP
# 95803   2401   2.216304     242  192.168.10.5  216.58.209.238     HTTP
# 95804   2402   2.216304     242  192.168.10.5  216.58.209.238     HTTP
# 98613   5211  44.625846     242  192.168.10.5  216.58.209.238     HTTP
# 98614   5212  44.625846     242  192.168.10.5  216.58.209.238     HTTP
# 111940  3337   8.063204     242  192.168.10.5  216.58.209.238     HTTP
# 111941  3338   8.063204     242  192.168.10.5  216.58.209.238     HTTP
# 114750  6147  53.842646     242  192.168.10.5  216.58.209.238     HTTP
# 114751  6148  53.842646     242  192.168.10.5  216.58.209.238     HTTP
#
#                    Info  Class  Predict
# 18300   GET / HTTP/1.1       1        1
# 18301   GET / HTTP/1.1       1        1
# 21110   GET / HTTP/1.1       1        1
# 21111   GET / HTTP/1.1       1        1
# 95803   GET / HTTP/1.1       1        1
# 95804   GET / HTTP/1.1       1        1
# 98613   GET / HTTP/1.1       1        1
# 98614   GET / HTTP/1.1       1        1
# 111940  GET / HTTP/1.1       1        1
# 111941  GET / HTTP/1.1       1        1
# 114750  GET / HTTP/1.1       1        1
# 114751  GET / HTTP/1.1       1        1

# %%
# Примеры ошибок модели
# Колонка Class - изначальная разметка (1 - атака, 0 - нормальный трафик), колонка Predict - результат работы ML-модели.
filt = (DS_valid["Predict"] == 1) & (DS_valid["Class"] == 0)
DS_valid[filt].sample(n=50).sort_index()
# Out:
#            No.        Time  Length         Source    Destination Protocol
# 8452    106056  305.684984      54   192.168.10.2   192.168.10.8      TCP  \
# 8539    106143  305.831626     125   192.168.10.5  192.168.10.10      TCP
# 8708    106312  306.158039      68   192.168.10.8   192.168.10.6      TCP
# 9155    106759  307.046402      54   192.168.10.5  192.168.10.10      TCP
# 9289    106893  307.281695      99   192.168.10.2   192.168.10.5      TCP
# 9383    106987  307.562339      81  192.168.10.10   192.168.10.5      TCP
# 9516    107120  307.808831      54   192.168.10.5   192.168.10.6      TCP
# 10092   107696  308.943791     140   192.168.10.7  192.168.10.10      TCP
# 10198   107802  309.135205     126   192.168.10.3   192.168.10.4      TCP
# 10294   107898  309.420118      54  192.168.10.10   192.168.10.7      TCP
# 10412   108016  309.657133      54   192.168.10.9   192.168.10.4      TCP
# 77111    61212  208.779597      54   192.168.10.8   192.168.10.3      TCP
# 10092    44253  >  12130 [<None>] Seq=4953 Win=400 Len=86      0        1
# 10198    25724  >  28885 [<None>] Seq=3749 Win=614 Len=72      0        1
# 10294     11152  >  46220 [<None>] Seq=2386 Win=362 Len=0      0        1
# 10412         7445  >  48878 [<None>] Seq=0 Win=956 Len=0      0        1
# 77111         62863  >  8089 [<None>] Seq=1 Win=562 Len=0      0        1
# 77196       22489  >  31769 [<None>] Seq=1 Win=509 Len=18      0        1
# 77251       17972  >  30822 [<None>] Seq=1 Win=463 Len=83      0        1
# 77398        17570  >  22475 [<None>] Seq=1 Win=866 Len=0      0        1
# 77758       32521  >  41536 [<None>] Seq=1 Win=894 Len=71      0        1
# 77986        34477  >  10420 [<None>] Seq=1 Win=524 Len=0      0        1
# 78053       27418  >  11795 [<None>] Seq=1 Win=975 Len=16      0        1
# 78090       37741  >  21174 [<None>] Seq=1 Win=777 Len=95      0        1
# 78155         1230  >  43987 [<None>] Seq=1 Win=752 Len=0      0        1
# 78350        31662  >  8123 [<None>] Seq=1 Win=487 Len=98      0        1
# 78736       63233  >  41839 [<None>] Seq=1 Win=647 Len=86      0        1
# 78786         17284  >  5464 [<None>] Seq=1 Win=593 Len=0      0        1
# 78888        31314  >  59945 [<None>] Seq=1 Win=695 Len=0      0        1
# 78984           57138  >  51823 [FIN] Seq=1 Win=734 Len=0      0        1
# 79004        54005  >  48517 [<None>] Seq=1 Win=521 Len=0      0        1
# 79051       42808  >  35404 [<None>] Seq=1 Win=262 Len=30      0        1
# 79068       14276  >  20500 [<None>] Seq=1 Win=989 Len=76      0        1
# 79238        32368  >  9146 [<None>] Seq=1 Win=496 Len=86      0        1
# 107932  Event: <Unknown eventcode 88>, <Unknown eventc...      0        1
# 209342  46139  >  27996 [<None>] Seq=3780 Win=133 Len=100      0        1
# 209382       45672  >  17775 [<None>] Seq=0 Win=451 Len=0      0        1
# 209495    35388  >  6929 [<None>] Seq=1226 Win=773 Len=56      0        1
# 209692       26802  >  39699 [FIN] Seq=1786 Win=398 Len=0      0        1
# 209719        7272  >  35262 [<None>] Seq=0 Win=274 Len=0      0        1
# 210227       16967  >  62708 [<None>] Seq=0 Win=947 Len=0      0        1
# 210237       21269  >  20851 [<None>] Seq=0 Win=283 Len=0      0        1
# 210319    9143  >  48288 [<None>] Seq=4032 Win=186 Len=65      0        1
# 210461       47498  >  37281 [<None>] Seq=0 Win=107 Len=0      0        1
# 210857        61703  >  4144 [<None>] Seq=0 Win=174 Len=0      0        1
# 211167         4141  >  7004 [<None>] Seq=0 Win=172 Len=0      0        1
# 211178        1429  >  41625 [SYN] Seq=3523 Win=918 Len=0      0        1
# 211321        58871  >  8975 [FIN] Seq=3989 Win=513 Len=0      0        1
# 211482    18942  >  1621 [<None>] Seq=2912 Win=467 Len=82      0        1
# 212189  15484  >  5445 [<None>] Seq=2004 Win=776 Len=8...      0        1
# 212260   52516  >  27662 [<None>] Seq=2972 Win=197 Len=47      0        1
# 212502       54146  >  35451 [SYN] Seq=3273 Win=342 Len=0      0        1
# 212546        48019  >  3391 [<None>] Seq=0 Win=629 Len=0      0        1
# 212980       41994  >  59444 [<None>] Seq=0 Win=708 Len=0      0        1
# 213025        3880  >  24007 [FIN] Seq=4661 Win=912 Len=0      0        1
